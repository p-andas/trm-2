# %%
import torch
print(torch.__version__)
# Out:
# 2.3.0+cu121

# %%
import torch
print(torch.cuda.is_available())        # Should return True
print(torch.cuda.device_count())        # Number of GPUs detected
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA H100 PCIe

# %%
import os

# Make CUDA operations synchronous for accurate error reporting
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

import torch

# Check if GPU is available
print("CUDA available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA available: True
# Device name: NVIDIA H100 PCIe

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU")

# Create a tensor and move it to the device
x = torch.randn(1000, 1000, device=device)
y = torch.randn(1000, 1000, device=device)

# Perform a computation on the GPU
z = x @ y  # Matrix multiplication
print("Computation done on:", z.device)
# Out:
# GPU is available: NVIDIA H100 PCIe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 12
#       9     print("GPU not available, using CPU")
#      11 # Create a tensor and move it to the device
# ---> 12 x = torch.randn(1000, 1000, device=device)
#      13 y = torch.randn(1000, 1000, device=device)
#      15 # Perform a computation on the GPU
#
# RuntimeError: CUDA error: CUDA-capable device(s) is/are busy or unavailable
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.3.0+cu121
# 12.1

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.0+cu121
